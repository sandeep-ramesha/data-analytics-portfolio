# %%
What is file handling?
it will allow us to create, read, write and update and deleate files. it is used to store data permanently/tem.

the built-in function is open() to work with files
common modes:
1) "r" - read
2) "w" - write
3) "a" - append
4) "b" - binary
5) "rb" - read binary
6) "wt" - write text
7) "t" - text

File path:
relative path: file name
absolute path: directories(complete loc) + file names

# %%
data = open("demo.txt","r")

# %%
data.read()
# Out:
# "My name is aaaa and i'm from bbb "

# %%
data.close()

# %%
data.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data.read()
#
# ValueError: I/O operation on closed file.

# %%
d1 = open(r"/Users/sandeepr/Desktop/Bio.docx","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 d1 = open(r"Users/sandeepr/Desktop/Bio.docx","r")
#
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Users/sandeepr/Desktop/Bio.docx'

# %%
d1.read()
# Out:
# ''

# %%
d1.close()

# %%
s1 = open("sample.txt","w")

# %%
s1.write("Hello how are you?")
# Out:
# 18

# %%
s2 = (r"/Users/sandeepr/Desktop/sample2.txt","w")
s2.write("How's it going")
s2.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 s2 = (r"/Users/sandeepr/Desktop/sample2.txt","w")
# ----> 2 s2.write("How's it going")
#       3 s2.close()
#
# AttributeError: 'tuple' object has no attribute 'write'

# %%
s3 = open("sample.txt","a")
s3.append("What you doing")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 s3 = open("sample.txt","a")
# ----> 2 s3.append("What you doing")
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'append'

# %%
import os

# %%
os.remove("sample.txt")
